# %% [markdown]
# # Deep Deterministic Policy Gradients (DDPG)
# ---
# In this notebook, we train DDPG with OpenAI Gym's BipedalWalker-v2 environment.
#
# ### 1. Import the Necessary Packages

# %%
import gym
import random
import torch
import numpy as np
from collections import deque
import matplotlib.pyplot as plt
# %matplotlib inline

from ddpg_agent import Agent

# %% [markdown]
# ### 2. Instantiate the Environment and Agent

# %%
env = gym.make('BipedalWalker-v3')
env.seed(10)
agent = Agent(state_size=env.observation_space.shape[0], action_size=env.action_space.shape[0], random_seed=10)

# %% [markdown]
# ### 3. Train the Agent with DDPG
#
# Run the code cell below to train the agent from scratch.  Alternatively, you can skip to the next code cell to load the pre-trained weights from file.

# %%
def ddpg(n_episodes=2000, max_t=700):
    scores_deque = deque(maxlen=100)
    scores = []
    max_score = -np.Inf
    for i_episode in range(1, n_episodes+1):
        state = env.reset()
        agent.reset()
        score = 0
        for t in range(max_t):
            action = agent.act(state)
            next_state, reward, done, _ = env.step(action)
            agent.step(state, action, reward, next_state, done)
            state = next_state
            score += reward
            if done:
                break 
        scores_deque.append(score)
        scores.append(score)
        print('\rEpisode {}\tAverage Score: {:.2f}\tScore: {:.2f}'.format(i_episode, np.mean(scores_deque), score), end="")
        if i_episode % 100 == 0:
            torch.save(agent.actor_local.state_dict(), 'checkpoint_actor.pth')
            torch.save(agent.critic_local.state_dict(), 'checkpoint_critic.pth')
            print('\rEpisode {}\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_deque)))   
    return scores

scores = ddpg()

fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(1, len(scores)+1), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')
plt.show()
# Out:
# Episode 100	Average Score: -98.73
# Episode 200	Average Score: -114.72
# Episode 300	Average Score: -80.35
# Episode 400	Average Score: -63.88
# Episode 500	Average Score: -70.63
# Episode 600	Average Score: -59.01
# Episode 700	Average Score: -70.66
# Episode 800	Average Score: -44.08
# Episode 900	Average Score: -69.06
# Episode 1000	Average Score: -100.89
# Episode 1100	Average Score: -109.90
# Episode 1200	Average Score: -47.10
# Episode 1300	Average Score: -111.18
# Episode 1400	Average Score: -97.02
# Episode 1500	Average Score: -101.06
# Episode 1600	Average Score: -74.74
# Episode 1700	Average Score: -108.48
# Episode 1800	Average Score: -95.58
# Episode 1900	Average Score: -77.79
# Episode 2000	Average Score: -81.89

# %% [markdown]
# ### 4. Watch a Smart Agent!
#
# In the next code cell, you will load the trained weights from file to watch a smart agent!

# %%
agent.actor_local.load_state_dict(torch.load('checkpoint_actor.pth'))
agent.critic_local.load_state_dict(torch.load('checkpoint_critic.pth'))

state = env.reset()
agent.reset()   
while True:
    action = agent.act(state)
    env.render()
    next_state, reward, done, _ = env.step(action)
    state = next_state
    if done:
        break
        
env.close()
# Out:
# /Users/jhp/GitHub/deep-reinforcement-learning/venv-udacity/lib/python3.6/site-packages/torch/nn/functional.py:1698: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~/GitHub/deep-reinforcement-learning/venv-udacity/lib/python3.6/site-packages/gym/envs/classic_control/rendering.py in <module>
#      24 try:
# ---> 25     from pyglet.gl import *
#      26 except ImportError as e:
#
# ~/GitHub/deep-reinforcement-learning/venv-udacity/lib/python3.6/site-packages/pyglet/gl/__init__.py in <module>
#      94
# ---> 95 from pyglet.gl.lib import GLException
#      96 from pyglet.gl.gl import *
#
# ~/GitHub/deep-reinforcement-learning/venv-udacity/lib/python3.6/site-packages/pyglet/gl/lib.py in <module>
#     146 elif pyglet.compat_platform == 'darwin':
# --> 147     from pyglet.gl.lib_agl import link_GL, link_GLU, link_AGL
#     148 else:
#
# ~/GitHub/deep-reinforcement-learning/venv-udacity/lib/python3.6/site-packages/pyglet/gl/lib_agl.py in <module>
#      42
# ---> 43 gl_lib = pyglet.lib.load_library(framework='/System/Library/Frameworks/OpenGL.framework')
#      44 agl_lib = pyglet.lib.load_library(framework='/System/Library/Frameworks/AGL.framework')
#
# ~/GitHub/deep-reinforcement-learning/venv-udacity/lib/python3.6/site-packages/pyglet/lib.py in load_library(self, *names, **kwargs)
#     123         if 'framework' in kwargs and self.platform == 'darwin':
# --> 124             return self.load_framework(kwargs['framework'])
#     125
#
# ~/GitHub/deep-reinforcement-learning/venv-udacity/lib/python3.6/site-packages/pyglet/lib.py in load_framework(self, path)
#     278
# --> 279         raise ImportError("Can't find framework %s." % path)
#     280
#
# ImportError: Can't find framework /System/Library/Frameworks/OpenGL.framework.
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-8-3364b74a92c2> in <module>
#       6 while True:
#       7     action = agent.act(state)
# ----> 8     env.render()
#       9     next_state, reward, done, _ = env.step(action)
#      10     state = next_state
#
# ~/GitHub/deep-reinforcement-learning/venv-udacity/lib/python3.6/site-packages/gym/core.py in render(self, mode, **kwargs)
#     238
#     239     def render(self, mode='human', **kwargs):
# --> 240         return self.env.render(mode, **kwargs)
#     241
#     242     def close(self):
#
# ~/GitHub/deep-reinforcement-learning/venv-udacity/lib/python3.6/site-packages/gym/envs/box2d/bipedal_walker.py in render(self, mode)
#     447
#     448     def render(self, mode='human'):
# --> 449         from gym.envs.classic_control import rendering
#     450         if self.viewer is None:
#     451             self.viewer = rendering.Viewer(VIEWPORT_W, VIEWPORT_H)
#
# ~/GitHub/deep-reinforcement-learning/venv-udacity/lib/python3.6/site-packages/gym/envs/classic_control/rendering.py in <module>
#      30     If you're running on a server, you may need a virtual frame buffer; something like this should work:
#      31     'xvfb-run -s \"-screen 0 1400x900x24\" python <your_script.py>'
# ---> 32     ''')
#      33
#      34 import math
#
# ImportError:
#     Error occurred while running `from pyglet.gl import *`
#     HINT: make sure you have OpenGL install. On Ubuntu, you can run 'apt-get install python-opengl'.
#     If you're running on a server, you may need a virtual frame buffer; something like this should work:
#     'xvfb-run -s "-screen 0 1400x900x24" python <your_script.py>'

# %% [markdown]
# ### 5. Explore
#
# In this exercise, we have provided a sample DDPG agent and demonstrated how to use it to solve an OpenAI Gym environment.  To continue your learning, you are encouraged to complete any (or all!) of the following tasks:
# - Amend the various hyperparameters and network architecture to see if you can get your agent to solve the environment faster than this benchmark implementation.  Once you build intuition for the hyperparameters that work well with this environment, try solving a different OpenAI Gym task!
# - Write your own DDPG implementation.  Use this code as reference only when needed -- try as much as you can to write your own algorithm from scratch.
# - You may also like to implement prioritized experience replay, to see if it speeds learning.
# - The current implementation adds Ornsetein-Uhlenbeck noise to the action space.  However, it has [been shown](https://blog.openai.com/better-exploration-with-parameter-noise/) that adding noise to the parameters of the neural network policy can improve performance.  Make this change to the code, to verify it for yourself!
# - Write a blog post explaining the intuition behind the DDPG algorithm and demonstrating how to use it to solve an RL environment of your choosing.
